# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Crop Production data.csv')
df
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                            ...           ...        ...          ...
# 51948                 Chhattisgarh     KONDAGAON       2011  Kharif
# 51949                 Chhattisgarh     KONDAGAON       2011  Kharif
# 51950                 Chhattisgarh     KONDAGAON       2011  Kharif
# 51951                 Chhattisgarh     KONDAGAON       2011  Kharif
# 51952                 Chhattisgarh     KONDAGAON       2011  Kharif
#
#                       Crop     Area  Production
# 0                 Arecanut   1254.0      2000.0
# ...

# %%
df.shape
# Out:
# (51953, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51953 entries, 0 to 51952
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State_Name     51953 non-null  object
#  1   District_Name  51953 non-null  object
#  2   Crop_Year      51953 non-null  int64
#  3   Season         51953 non-null  object
#  4   Crop           51953 non-null  object
#  5   Area           51953 non-null  float64
#  6   Production     51700 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.8+ MB

# %%
df.describe()
# Out:
#           Crop_Year           Area    Production
# count  51953.000000   51953.000000  5.170000e+04
# mean    2005.937771    7338.703445  3.982276e+05
# std        5.085025   27965.401646  1.209577e+07
# min     1997.000000       0.200000  0.000000e+00
# 25%     2002.000000      74.000000  8.300000e+01
# 50%     2006.000000     426.000000  6.070000e+02
# 75%     2010.000000    2500.000000  5.269000e+03
# max     2014.000000  877029.000000  7.801620e+08

# %%
df.dtypes    #chexking data types
# Out:
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Crop              object
# Area             float64
# Production       float64
# dtype: object

# %%
df.isnull().sum() #checking for null values
# Out:
# State_Name         0
# District_Name      0
# Crop_Year          0
# Season             0
# Crop               0
# Area               0
# Production       253
# dtype: int64

# %%
mean_production =df['Production'].mean()
df['Production'].fillna(mean_production, inplace=True)    #filling the null values with mean value

# %%
df.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
df.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
# Plotting categorical and numerical variables

# %%
sns.countplot(data=df,x = "State_Name")

plt.xticks(rotation = 90)
plt.show()

# %%
df.State_Name.value_counts()[:10].plot(kind = "bar",color="grey")
# Out:
# <Axes: xlabel='State_Name'>

# %%
df.District_Name.value_counts()[:10].plot(kind = "bar",color="orange")
# Out:
# <Axes: xlabel='District_Name'>

# %%
sns.countplot(data=df, x = "Crop",color="skyblue")
plt.xticks(rotation = 90)
plt.show()

# %%
df.Crop.value_counts()[:10]
# Out:
# Crop
# Rice                 3906
# Maize                3303
# Moong(Green Gram)    2182
# Dry chillies         1649
# Arhar/Tur            1632
# Urad                 1623
# Sugarcane            1565
# Wheat                1551
# Sesamum              1534
# Small millets        1449
# Name: count, dtype: int64

# %%
df.Crop.value_counts()[:10].plot(kind = "bar",color="yellow")
# Out:
# <Axes: xlabel='Crop'>

# %%
sns.countplot(data=df, x ="Crop_Year",color='green')

plt.xticks(rotation = 90)
plt.show()

# %%
sns.histplot(data =df, x = "Production", bins = 10,color='pink')
plt.show()

# %%
sns.histplot(data=df, x = "Area", bins = 10,color='red')
plt.show()

# %%
# checking for outliers

# %%
sns.boxplot(data=df, x = "Production")
# Out:
# <Axes: xlabel='Production'>

# %%
sns.boxplot(data=df, x = "Area")
# Out:
# <Axes: xlabel='Area'>

# %%
# not treating the outliers for the sake of data integrity,preservation and to ensure analysis reflects correct trends

# %%
# Which state has highest production?
production_by_state = df.groupby('State_Name')['Production'].sum()
state_with_highest_production = production_by_state.idxmax()
highest_production_value = production_by_state.max()
state_with_highest_production
# Out:
# 'Andhra Pradesh'

# %%
df.groupby(["State_Name"]).agg({"Production" : "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='State_Name'>

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop', 'Area',
#        'Production'],
#       dtype='object')

# %%
# which crop has highest area?
ax = sns.barplot(data = df.head(10),  x= "Crop", y = "Area")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# <ipython-input-32-dce23a8eb9f1>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %%
# which season has highest production and how much?
max_season =df.loc[df['Production'].idxmax(), 'Season']
max_production =df['Production'].max()
print(f"The season with the highest production is {max_season} with a production of {max_production}")
# Out:
# The season with the highest production is Whole Year  with a production of 780162000.0

# %%
# which year has highest production?
ax = sns.barplot(data=df,  x= "Crop_Year", y = "Production",color="brown")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# <ipython-input-45-9cbc050daaf3>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.to_csv('/content/Crop Production data.csv', index=False)

# %% [markdown]
# # conclusion
# The analysis of crop production dataset shows the relationship and distribution of production over the areas over respective years.
# The trend in production over the years is disruptive and doesn't follow a pattern.Whereas the production is mostly seen whole year as there are variety of crops which grow in different seasons.The highest production was seen in the year 2013 and the area with highest production is Andhra Pradesh.The crop which is mostly produced is coconut.Outliers were not treated for the sake of data integrity and considering the type of data.
